# %%
import json
import requests
import os
from PIL import Image
from io import BytesIO

# %% [markdown]
# Para realizar esta búsqueda, y obtener los posters de las películas deseadas, tendremos que tener en cuenta que antes necesitamos generar una ApiKey, proporcionada en la misma web "www.omdbapi.com", además encontraremos los pasos a seguir para encontrar lo que queramos de estas pelicúlas.

# %% [markdown]
# ### GIGI

# %%
data = requests.get("http://www.omdbapi.com/?s=gigi&apikey=c9435740").json()
data
# Out:
# {'Search': [{'Title': 'Gigi',
#    'Year': '1958',
#    'imdbID': 'tt0051658',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMWIzNzlkMWUtY2VhYy00NWMwLTg3MWUtZWY4ODZjMjBiMmM1XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SX300.jpg'},
#   {'Title': 'This Is Everything: Gigi Gorgeous',
#    'Year': '2017',
#    'imdbID': 'tt5875666',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMjU0NzE5NTE1MF5BMl5BanBnXkFtZTgwMzAwODkzMTI@._V1_SX300.jpg'},
#   {'Title': 'Gigi',
#    'Year': '1949',
#    'imdbID': 'tt0041414',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BNTljNTI1N2ItNWQyNS00NDNmLThmYTQtZmExNmIzZTFiZDBkXkEyXkFqcGdeQXVyMTIxOTk5MzY@._V1_SX300.jpg'},
#   {'Title': 'Gigi Does It',
#    'Year': '2015',
#    'imdbID': 'tt5070488',
#    'Type': 'series',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BNTg5NDM5ODQ2MV5BMl5BanBnXkFtZTgwMDMwODYwNzE@._V1_SX300.jpg'},
#   {'Title': 'Gigi: Almost American',
# ...

# %%
#Vemos que hay mas de una película que contiene Gigi en el titulo.

# %%
data.keys()
# Out:
# dict_keys(['Search', 'totalResults', 'Response'])

# %%
#Sacamos las keys y elegimos la primera pelicula que es la que queremos.

# %%
Search = data["Search"]
Gigi = Search[0]
Gigi
# Out:
# {'Title': 'Gigi',
#  'Year': '1958',
#  'imdbID': 'tt0051658',
#  'Type': 'movie',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWIzNzlkMWUtY2VhYy00NWMwLTg3MWUtZWY4ODZjMjBiMmM1XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SX300.jpg'}

# %%
#Aunque ya podríamos coger la url del poster que queremos, vamos a llegar hasta el final.

# %%
Poster = Gigi["Poster"]
Poster
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMWIzNzlkMWUtY2VhYy00NWMwLTg3MWUtZWY4ODZjMjBiMmM1XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SX300.jpg'

# %%
url = "https://m.media-amazon.com/images/M/MV5BMWIzNzlkMWUtY2VhYy00NWMwLTg3MWUtZWY4ODZjMjBiMmM1XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SX300.jpg"

# %%
#Lo que hacemos aquí es coger la url, dentro de la variable "url", y sale de output la imagen que proviene de esa URL.
poster = Image.open(requests.get(url, stream=True).raw)
poster
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x463 at 0x7F86C1F10C70>

# %% [markdown]
# ### THE ENGLISH PATIENT

# %%
#Aquí recortamos pasos, y vamos directos a coger la url que queremos.
data2 = requests.get("http://www.omdbapi.com/?s=The+English+Patient&apiKey=c9435740").json()
data2
# Out:
# {'Search': [{'Title': 'The English Patient',
#    'Year': '1996',
#    'imdbID': 'tt0116209',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BOTkxZTdkNTQtM2QwOS00NzRlLWEyMGItYTcxOTE4NTgyNGVhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg'}],
#  'totalResults': '1',
#  'Response': 'True'}

# %%
url2 = "https://m.media-amazon.com/images/M/MV5BOTkxZTdkNTQtM2QwOS00NzRlLWEyMGItYTcxOTE4NTgyNGVhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg"
poster2 = Image.open(requests.get(url2, stream=True).raw)
poster2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x445 at 0x7F86C2571280>

# %% [markdown]
# ### PARASITE

# %%
data3 = requests.get("http://www.omdbapi.com/?s=parasite&apiKey=c9435740").json()
data3
# Out:
# {'Search': [{'Title': 'Parasite',
#    'Year': '2019',
#    'imdbID': 'tt6751668',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_SX300.jpg'},
#   {'Title': 'Parasite',
#    'Year': '1982',
#    'imdbID': 'tt0084472',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMTFlZDVjMDMtODkwNS00MTM3LWJiMzQtY2IxN2JiNWZjMWUxXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg'},
#   {'Title': 'Parasite Eve',
#    'Year': '1997',
#    'imdbID': 'tt0119860',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM5MTMzMTAzMl5BMl5BanBnXkFtZTcwMzQ2OTAyMQ@@._V1_SX300.jpg'},
#   {'Title': 'Sexual Parasite: Killer Pussy',
#    'Year': '2004',
#    'imdbID': 'tt0434125',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY3MjE0MTA3Nl5BMl5BanBnXkFtZTcwNTE0MjE2MQ@@._V1_SX300.jpg'},
#   {'Title': 'Parasite Dolls',
# ...

# %%
Search = data3["Search"]
parasite = Search[0]
parasite
# Out:
# {'Title': 'Parasite',
#  'Year': '2019',
#  'imdbID': 'tt6751668',
#  'Type': 'movie',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_SX300.jpg'}

# %%
Poster3 = parasite["Poster"]
Poster3
# Out:
# 'https://m.media-amazon.com/images/M/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_SX300.jpg'

# %%
url3 = "https://m.media-amazon.com/images/M/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_SX300.jpg"
poster3 = Image.open(requests.get(url3, stream=True).raw) 
poster3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x445 at 0x7F86C2571E20>
