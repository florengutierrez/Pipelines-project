# %%
import numpy as np
import pandas as pd
import requests
from functions import *
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_IMDb = check_csv()
# Out:
# /Users/florengutierrez/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
def cleaning(df_IMDb):
    
    df_IMDb.drop(df_IMDb[df_IMDb.Year.isnull()].index, inplace = True)

    df_IMDb.rename(columns = {"Title": "Film"}, inplace=True)

    IMDb = df_IMDb.sort_values("Avg_vote",ascending=False)
    
    return IMDb

# %%
cleaning(df_IMDb)
# Out:
#                                           Film  Year             Genre  \
# 83275                          Suvarna Sundari  2019  Action, Thriller
# 84995                              Notuku Potu  2017   Horror, Mystery
# 55310                                   Jeeudo  2020    Drama, Romance
# 56032                                       Ek  2019     Action, Drama
# 54217        Lejos de Casa pelicula Venezolana  2020    Drama, History
# ...                                        ...   ...               ...
# 78944                   Utsuroi no hyÃ´honbako  2016            Comedy
# 55972                           Prema Panjaram  1991     Drama, Family
# 75895                  Ritoru Kyouta no bouken  2017         Adventure
# 76389  Chun jie xin ling: Zhu meng yan yi quan  2015     Comedy, Drama
# 76216                              A no dentou  2014             Drama
#
#        Duration    Country           Director  \
# 83275       120      India          Msn Surya
# 84995       121      India       Basheed S.K.
# 55310       150      India      Aalmist Subba
# 56032       129      India      Sampath Rudra
# 54217        87  Venezuela     Abner Official
# ...         ...        ...                ...
# 78944        95      Japan     Keiko Tsuruoka
# 55972       138      India  Ramana Reddy B.V.
# 75895        82      Japan      Satsuki Okawa
# 76389        96      China          Zhifei Bi
# 76216        53      Japan     Keiko Tsuruoka
#
#                                            Writer  \
# 83275                                         NaN
# 84995                                         NaN
# 55310               Aalmist Subba, Chanchal Thapa
# 56032                               Harik Krishna
# 54217                Dariana Jozh, Abner Official
# ...                                           ...
# 78944                              Keiko Tsuruoka
# 55972  Ramana Reddy B.V., Gopalakrishna Paruchuri
# 75895                               Satsuki Okawa
# 76389                                   Zhifei Bi
# 76216                              Keiko Tsuruoka
#
#                                                   Actors  \
# 83275  Shamna Kasim, Sakshi Chaudhary, Jaya Prada, Av...
# 84995          Mumait Khan, Manisha Koirala, Arjun Sarja
# 55310  Prashant Baraili, Davina, Pranisha Gahatraj, P...
# 56032  Bishnu Adhikari, Himanshi Khurana, Aparna Shar...
# 54217  Angibell, Gabriel Buitrago, Darwing, Dariana J...
# ...                                                  ...
# 78944  Mone Sakuragi, Gen Ogawa, Moeru Akazome, KÃ´su...
# 55972  Mohan Babu, Brahmanandam, Harish, Madhubala, G...
# 75895  Tao Tsuchiya, Misa Shimizu, Hidekazu Mashima, ...
# 76389                                                NaN
# 76216  Suzuna Kinosuta, Mariko Kobayashi, Akaji Maro,...
#
#                                              Description  Avg_vote
# 83275  The movie revolves around an idol, Suvarna Sun...       9.9
# 84995  Notuku Potu is a crime story laced with elemen...       9.8
# 55310  "A TALE OF LOVE, MYTH, AND FATE" "JEEUDO" (mea...       9.8
# 56032  EK is a love story set in the context of ever ...       9.8
# 54217  Samuel, a young Venezuelan, emigrates from his...       9.8
# ...                                                  ...       ...
# 78944  A women challenges herself to do more and over...       1.0
# 55972                                                NaN       1.0
# 75895                                                NaN       1.0
# 76389  Pure Hearts: Into Chinese Showbiz is the maide...       1.0
# 76216  Can the friendship and bond between two brothe...       1.0
#
# [85855 rows x 10 columns]

# %% [markdown]
# - Realizamos el top10 y exportamos, para luego lanzar una hipótesis en visualization-ipynb.

# %%
def IMDb_top10(IMDb):
    
    IMDb_top10 = IMDb.head(10)
    
    IMDb_top10.set_index("Film")
    
    return IMDb_top10

# %%
IMDb_top10(IMDb)
# Out:
#                                     Film  Year             Genre  Duration  \
# 83275                    Suvarna Sundari  2019  Action, Thriller       120
# 84995                        Notuku Potu  2017   Horror, Mystery       121
# 55310                             Jeeudo  2020    Drama, Romance       150
# 56032                                 Ek  2019     Action, Drama       129
# 54217  Lejos de Casa pelicula Venezolana  2020    Drama, History        87
# 84434                Vaarthakal Ithuvare  2019            Comedy       121
# 56329                          Meka Suri  2020   Crime, Thriller        86
# 58809                      Hopeful Notes  2010             Drama        94
# 54166                The Moving on Phase  2020            Comedy        85
# 55170                               Isha  2020     Drama, Horror       118
#
#          Country          Director                         Writer  \
# 83275      India         Msn Surya                            NaN
# 84995      India      Basheed S.K.                            NaN
# 55310      India     Aalmist Subba  Aalmist Subba, Chanchal Thapa
# 56032      India     Sampath Rudra                  Harik Krishna
# 54217  Venezuela    Abner Official   Dariana Jozh, Abner Official
# 84434      India        Manoj Nair                     Manoj Nair
# 56329      India  Trinadh Velisila                            NaN
# 58809        USA    Valerio Zanoli                 Valerio Zanoli
# 54166        USA     Don Tjernagel                  Don Tjernagel
# 55170      India       Jose Thomas                    Jose Thomas
#
#                                                   Actors  \
# 83275  Shamna Kasim, Sakshi Chaudhary, Jaya Prada, Av...
# 84995          Mumait Khan, Manisha Koirala, Arjun Sarja
# 55310  Prashant Baraili, Davina, Pranisha Gahatraj, P...
# 56032  Bishnu Adhikari, Himanshi Khurana, Aparna Shar...
# 54217  Angibell, Gabriel Buitrago, Darwing, Dariana J...
# 84434  Siju Wilson, Nandu, Vinay Forrt, Mammukoya, Al...
# 56329  Abhinay, Naresh Byreddy, Sharat Kumar, Sravan,...
# 58809  Walter Nudo, Colin Ross, Ian Poland, Laural Me...
# 54166  Matt Anderson, Clint Boevers, Jillian Brown, C...
# 55170                      Kishore Satya, Abhishek Vinod
#
#                                              Description  Avg_vote
# 83275  The movie revolves around an idol, Suvarna Sun...       9.9
# 84995  Notuku Potu is a crime story laced with elemen...       9.8
# 55310  "A TALE OF LOVE, MYTH, AND FATE" "JEEUDO" (mea...       9.8
# 56032  EK is a love story set in the context of ever ...       9.8
# 54217  Samuel, a young Venezuelan, emigrates from his...       9.8
# 84434  Ittan Pillai, the police station head finds hi...       9.7
# 56329  The story revolves around Meka Suri, a butcher...       9.7
# 58809  A young violinist with leukemia brings hope an...       9.7
# 54166  Piper is a young adult female that is forced i...       9.5
# 55170                                                NaN       9.5

# %%
IMDb_top10.to_csv("top10_IMDb.csv")

# %%
df_oscars = oscars()
df_oscars = df_oscars.drop(["Year"], axis="columns")
df_oscars = df_oscars.sort_values("Awards",ascending=False)
df_oscars
# Out:
#                       Film Awards Nominations
# 466       The Last Emperor      9           9
# 942                   Gigi      9           9
# 333    The English Patient      9          12
# 951     Gone with the Wind  8 (2)          13
# 510                Amadeus      8          11
# ...                    ...    ...         ...
# 986    The House I Live In  0 (1)           0
# 1221           Sweethearts  0 (1)           2
# 735     Planet of the Apes  0 (1)           2
# 1074      Monsieur Vincent  0 (1)           0
# 931   A Force in Readiness  0 (1)           0
#
# [1317 rows x 3 columns]

# %%
Oscar_top10 = df_oscars.head(10)
Oscar_top10 = Oscar_top10.set_index("Film")
Oscar_top10
# Out:
#                       Awards Nominations
# Film
# The Last Emperor           9           9
# Gigi                       9           9
# The English Patient        9          12
# Gone with the Wind     8 (2)          13
# Amadeus                    8          11
# Slumdog Millionaire        8          10
# Gandhi                     8          11
# From Here to Eternity      8          13
# Cabaret                    8          10
# My Fair Lady               8          12

# %%
df_merge = pd.merge(df_IMDb, df_oscars, on='Film')
df_merge = df_merge.drop([2])
df_merge = df_merge.head(25)
df_merge.head()
# Out:
#        Film  Year                         Genre  Duration  \
# 0  Parasite  2019       Comedy, Drama, Thriller       132
# 1  Whiplash  2014                  Drama, Music       106
# 3     Joker  2016                 Comedy, Drama       130
# 4      Coco  2017  Animation, Adventure, Family       105
# 5      1917  2019                    Drama, War       119
#
#                                 Country                      Director  \
# 0                           South Korea                  Bong Joon Ho
# 1                                   USA               Damien Chazelle
# 3                                 India  Raju Murugan, Raju Saravanan
# 4                                   USA    Lee Unkrich, Adrian Molina
# 5  USA, UK, India, Spain, Canada, China                    Sam Mendes
#
#                              Writer  \
# 0        Bong Joon Ho, Bong Joon Ho
# 1                   Damien Chazelle
# 3                      Raju Murugan
# 4           Lee Unkrich, Jason Katz
# 5  Sam Mendes, Krysty Wilson-Cairns
#
#                                               Actors  \
# 0  Kang-ho Song, Sun-kyun Lee, Yeo-jeong Jo, Woo-...
# 1  Miles Teller, J.K. Simmons, Paul Reiser, Melis...
# 3  Guru Somasundaram, Ramya Pandiyan, Gayathri, R...
# 4  Anthony Gonzalez, Gael GarcÃ­a Bernal, Benjami...
# 5  Dean-Charles Chapman, George MacKay, Daniel Ma...
#
#                                          Description  Avg_vote Awards  \
# 0  Greed and class discrimination threaten the ne...       8.6      4
# 1  A promising young drummer enrolls at a cut-thr...       8.5      3
# 3  Mannar (protagonist), a villager who declares ...       8.4      2
# 4  Aspiring musician Miguel, confronted with his ...       8.4      2
# 5  April 6th, 1917. As a regiment assembles to wa...       8.3      3
#
#   Nominations
# 0           6
# 1           5
# 3          11
# 4           2
# 5          10

# %%
df_merge.to_csv("merge.csv")
